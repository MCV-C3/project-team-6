# %%
import wandb
from tqdm import tqdm

# Replace with your organization, project, and sweep ID
entity = "mcv-team-6"  # your org name
project = "C3-Week3"      # your project name
sweep_id = "k5ns8jzl"         # your sweep ID

api = wandb.Api()
sweep = api.sweep(f"{entity}/{project}/{sweep_id}")

best_acc = 0
best_run = None

for run in tqdm(sweep.runs, desc="Scanning sweep runs"):
    
    history = run.history(keys=["test_accuracy"])
    
    acc = 0
    if not history.empty:
        acc = history["test_accuracy"].max()
    
    if acc > best_acc:
        best_acc = acc
        best_run = run
        

print(f"Best test_accuracy: {best_acc}")
print("Configuration that achieved it:")
for k, v in best_run.config.items():
    print(f"  {k}: {v}")
# Out:
# Scanning sweep runs: 100%|██████████| 122/122 [01:10<00:00,  1.74it/s]
# Best test_accuracy: 0.9562937062937062 at step None
# Configuration that achieved it:
#   lr: 2.1729679390519813e-05
#   optimizer: AdamW
#   batch_size: 32
#   weight_decay: 1.461506239963124e-05
#   label_smoothing: 0.02254139921835141

# %%
import wandb
from tqdm import tqdm

# Replace with your organization, project, and sweep ID
entity = "mcv-team-6"  # your org name
project = "C3-Week3"      # your project name
sweep_id = "ig5z7cnx"         # your sweep ID

api = wandb.Api()
sweep = api.sweep(f"{entity}/{project}/{sweep_id}")

best_acc = 0
best_run = None

for run in tqdm(sweep.runs, desc="Scanning sweep runs"):
    
    history = run.history(keys=["test_accuracy"])
    
    acc = 0
    if not history.empty:
        acc = history["test_accuracy"].max()
    
    if acc > best_acc:
        best_acc = acc
        best_run = run
        

print(f"Best test_accuracy: {best_acc}")
print("Configuration that achieved it:")
for k, v in best_run.config.items():
    print(f"  {k}: {v}")
# Out:
# wandb: Currently logged in as: aleix-armero73 (mcv-team-6) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Scanning sweep runs: 100%|██████████| 252/252 [02:05<00:00,  2.01it/s]
# Best test_accuracy: 0.9615384615384616
# Configuration that achieved it:
#   hue: 0.06272478548259297
#   blur: 0.442038986973481
#   crop: 0.1939592095722116
#   flip: 0.04855768013650663
#   grey: 0.331441327268726
#   scale: 0.999217703073204
#   shear: 29
#   affine: 0.623718831019832
#   jiggle: 0.2029549731865357
#   rotate: 0.13009412985538538
#   contrast: 0.7852337555662053
#   rotation: 16
#   brightness: 1.1237698676931558
#   crop_scale: 0.4382924444152586
#   saturation: 1.20141373248246
#   translate_x: 0.3584182906605954
#   translate_y: 0.035543949656199385
#   gaussian_noise_std: 1.190437323963532
#   gaussian_blur_kernel: 9
