# %%
from main import *
from bovw import *
from plotting import *

# %%
import os
import random
import numpy as np

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

# %%
data_train = Dataset(ImageFolder="../data/places_reduced/train")
data_test = Dataset(ImageFolder="../data/places_reduced/val")

len(data_train), len(data_test)
# Out:
# (8700, 2200)

# %%
random.shuffle(data_train)
random.shuffle(data_test)

enable_cache()

# %%
classifier_results = {}

codebook_sizes = [16, 32, 64, 128, 256]

for codebook_size in codebook_sizes:
    bovw_params = {
        "detector_type": "SIFT",
        "encoding_method": "fisher",
        "codebook_size": codebook_size,
        "descriptor_normalization": "L2",
        "joint_descriptor_normalization": "Standard",  #Necessary for Fisher Vectors in logistic regression
        "detector_kwargs": {"nfeatures": 1000},
        "dimensionality_reduction": "PCA", #Necessart for Fisher Vectors
        "dimensionality_reduction_kwargs": {"n_components": 64},
        "pyramid_levels": None, 
    }
    
    classifier_cls = LogisticRegression
    classifier_params = {
        "max_iter": 1000,
        "class_weight": "balanced",
    }
    
    scores = cross_validate_bovw(
        dataset=data_train,
        bovw_kwargs=bovw_params,
        classifier_cls=classifier_cls,
        classifier_kwargs=classifier_params,
        n_splits=5
    )
    
    classifier_results[codebook_size] = scores



print("\nSUMMARY")
for cb in classifier_results.keys():
    print(f"Cb Size={cb} -> Accuracy Train: {classifier_results[cb].train.accuracy.mean:.4f} ± {classifier_results[cb].train.accuracy.std:.4f}")
    print(f"Cb Size={cb} -> Accuracy Val: {classifier_results[cb].val.accuracy.mean:.4f} ± {classifier_results[cb].val.accuracy.std:.4f}")
    print()
# Out:
# Phase [Setup]: Extracting the descriptors:   6%|▌         | 512/8700 [00:02<00:31, 262.47it/s]
# Could not compute descriptors for image ../data/places_reduced/train\water_ice_snow\iceberg_00000023.jpg of class 9.
# Phase [Setup]: Extracting the descriptors:  59%|█████▊    | 5108/8700 [00:25<00:12, 291.08it/s]
# Could not compute descriptors for image ../data/places_reduced/train\mountains_hills_desert_sky\sky_00001410.jpg of class 5.
# Phase [Setup]: Extracting the descriptors: 100%|██████████| 8700/8700 [00:38<00:00, 228.66it/s]
#  40%|████      | 2/5 [09:29<14:14, 284.77s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 24
#      18     classifier_cls = LogisticRegression
#      19     classifier_params = {
#      20         "max_iter": 1000,
#      21         "class_weight": "balanced",
#      22     }
# ---> 24     scores = cross_validate_bovw(
#      25         dataset=data_train,
#      26         bovw_kwargs=bovw_params,
#      27         classifier_cls=classifier_cls,
#      28         classifier_kwargs=classifier_params,
#      29         n_splits=5
#      30     )
#      32     classifier_results[codebook_size] = scores
#      36 print("\nSUMMARY")
#
# File c:\Users\Adrià\Desktop\PC\Adrià\Estudis\Master\C3\project-team-6\Week1\main.py:450, in cross_validate_bovw(dataset, bovw_kwargs, classifier_cls, classifier_kwargs, n_splits, verbose)
#     447 bovw = BOVW(**bovw_kwargs)
#     448 classifier = classifier_cls(**classifier_kwargs)
# --> 450 bovw, classifier, train_scores = train_for_cv(train_data, bovw, classifier, verbose=verbose)
#     451 acc, prec, rec, f1 = test_for_cv(val_data, bovw, classifier, verbose=verbose)
#     453 train_accuracies.append(train_scores["accuracy"])
#
# File c:\Users\Adrià\Desktop\PC\Adrià\Estudis\Master\C3\project-team-6\Week1\main.py:373, in train_for_cv(train_data, bovw, classifier, verbose)
#     371     kmeans, cluster_centers = bovw._update_fit_codebook(descriptors=all_descriptors)
#     372 elif bovw.encoding_method == "fisher":
# --> 373     kmeans = bovw._update_fit_gmm(descriptors=all_descriptors)
#     374     cluster_centers = None
#     376 if verbose:
#
# File c:\Users\Adrià\Desktop\PC\Adrià\Estudis\Master\C3\project-team-6\Week1\bovw.py:201, in BOVW._update_fit_gmm(self, descriptors)
#     198 gm_args = self.codebook_kwargs.copy() if self.codebook_kwargs else {}
#     199 gm_args['covariance_type'] = 'diag'
# --> 201 self.gmm = learn_gmm(descriptors, n_modes=self.codebook_size, gm_args=gm_args)
#     203 return self.gmm
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\skimage\feature\_fisher_vector.py:150, in learn_gmm(descriptors, n_modes, gm_args)
#     147 else:
#     148     gmm = GaussianMixture(n_components=n_modes, covariance_type='diag')
# --> 150 gmm.fit(descriptors)
#     152 return gmm
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\mixture\_base.py:182, in BaseMixture.fit(self, X, y)
#     156 """Estimate model parameters with the EM algorithm.
#     157
#     158 The method fits the model ``n_init`` times and sets the parameters with
#    (...)    179     The fitted mixture.
#     180 """
#     181 # parameters are validated in fit_predict
# --> 182 self.fit_predict(X, y)
#     183 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\mixture\_base.py:251, in BaseMixture.fit_predict(self, X, y)
#     248 prev_lower_bound = lower_bound
#     250 log_prob_norm, log_resp = self._e_step(X)
# --> 251 self._m_step(X, log_resp)
#     252 lower_bound = self._compute_lower_bound(log_resp, log_prob_norm)
#     253 current_lower_bounds.append(lower_bound)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\mixture\_gaussian_mixture.py:830, in GaussianMixture._m_step(self, X, log_resp)
#     819 def _m_step(self, X, log_resp):
#     820     """M step.
#     821
#     822     Parameters
#    (...)    828         the point of each sample in X.
#     829     """
# --> 830     self.weights_, self.means_, self.covariances_ = _estimate_gaussian_parameters(
#     831         X, np.exp(log_resp), self.reg_covar, self.covariance_type
#     832     )
#     833     self.weights_ /= self.weights_.sum()
#     834     self.precisions_cholesky_ = _compute_precision_cholesky(
#     835         self.covariances_, self.covariance_type
#     836     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\mixture\_gaussian_mixture.py:289, in _estimate_gaussian_parameters(X, resp, reg_covar, covariance_type)
#     287 nk = resp.sum(axis=0) + 10 * np.finfo(resp.dtype).eps
#     288 means = np.dot(resp.T, X) / nk[:, np.newaxis]
# --> 289 covariances = {
#     290     "full": _estimate_gaussian_covariances_full,
#     291     "tied": _estimate_gaussian_covariances_tied,
#     292     "diag": _estimate_gaussian_covariances_diag,
#     293     "spherical": _estimate_gaussian_covariances_spherical,
#     294 }[covariance_type](resp, X, nk, means, reg_covar)
#     295 return nk, means, covariances
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\mixture\_gaussian_mixture.py:230, in _estimate_gaussian_covariances_diag(resp, X, nk, means, reg_covar)
#     210 def _estimate_gaussian_covariances_diag(resp, X, nk, means, reg_covar):
#     211     """Estimate the diagonal covariance vectors.
#     212
#     213     Parameters
#    (...)    228         The covariance vector of the current components.
#     229     """
# --> 230     avg_X2 = np.dot(resp.T, X * X) / nk[:, np.newaxis]
#     231     avg_means2 = means**2
#     232     return avg_X2 - avg_means2 + reg_covar
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\multiarray.py:750, in dot(a, b, out)
#     680     """
#     681     result_type(*arrays_and_dtypes)
#     682
#    (...)    745
#     746     """
#     747     return arrays_and_dtypes
# --> 750 @array_function_from_c_func_and_dispatcher(_multiarray_umath.dot)
#     751 def dot(a, b, out=None):
#     752     """
#     753     dot(a, b, out=None)
#     754
#    (...)    838
#     839     """
#     840     return (a, b, out)
#
# KeyboardInterrupt:

# %%
# Plot the validation accuracy vs pyramid levels
x_values = list(classifier_results.keys())
means = [classifier_results[cb].val.accuracy.mean for cb in x_values]
stds = [classifier_results[cb].val.accuracy.std for cb in x_values]

plot_cv_accuracy(
    x_values=x_values,
    means=means,
    stds=stds,
    descriptor_name="SIFT (codebook_size=512)",
    hyperparam_name="Pyramid Levels"
)
